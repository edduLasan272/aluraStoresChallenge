# %% [markdown]
# # **Análisis de Eficiencia en Ventas de Tiendas Departamentales**

# %% [markdown]
# ## Sección 01 - **Importanción de librerías**

# %%
# Sección 1: Importación de librerías:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Sección 2 - **Carga de datos desde varios archivos en un CSV con formato especial que contienen información de las ventas en tienda**

# %%
# Ruta del archivo | DATA:
ruta_dataStore01 = '/content/tiendasDepartamentales_tienda01.csv'
ruta_dataStore02 = '/content/tiendasDepartamentales_tienda02.csv'
ruta_dataStore03 = '/content/tiendasDepartamentales_tienda03.csv'
ruta_dataStore04 = '/content/tiendasDepartamentales_tienda04.csv'

# %%
# Asignamos a una varibale el dataframe de trabajo y lo igualamos a la lectura del archivo en conjunto con su ruta de acceso.
# El archivo es .csv, asumimos que contiene los datos concatenados o con una columna que indique la tienda:
dataStore01 = pd.read_csv(ruta_dataStore01)
dataStore02 = pd.read_csv(ruta_dataStore02)
dataStore03 = pd.read_csv(ruta_dataStore03)
dataStore04 = pd.read_csv(ruta_dataStore04)

# %%
# Vista preliminar de los datos:
print("\nPrimeras filas del dataset:")
print(dataStore01.head())
# Conocer el número de filas:
print("\nNúmero de filas en el dataset:")
print(len(dataStore01))
# Conocer el número de columnas:
print("\nNúmero de columnas en el dataset:")
print(len(dataStore01.columns))
print("\nNúmero de filas y columnas en el dataset:")
print(dataStore01.shape)
print("\nNombre de columnas disponibles:")
print(dataStore01.columns)
# Out:
# Primeras filas del dataset:
#             Producto Categoria del Producto  Precio  Costo de Envio  \
# 0  Asistente virtual           Electronicos  164300            6900
# 1    Mesa de comedor                Muebles  192300            8400
# 2      Juego de mesa               Juguetes  209600           15900
# 3         Microondas      Electrodomesticos  757500           41000
# 4   Silla de oficina                Muebles  335200           20200
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificacion  \
# 0      16/01/2021      Pedro Gomez          Bogota             4
# 1      18/05/2022  Beatriz Morales        Medellin             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3        3/5/2022   Juan Fernandez            Cali             4
# 4       7/11/2020    Maria Alfonso        Medellin             5
#
#        Metodo de Pago  Cantidad de Cuotas   Latitud  Longitud
# 0  Tarjeta de credito                   8   4.60971 -74.08175
# ...

# %%
# Vista preliminar de los datos:
print("\nPrimeras filas del dataset:")
print(dataStore02.head())
# Conocer el número de filas:
print("\nNúmero de filas en el dataset:")
print(len(dataStore02))
# Conocer el número de columnas:
print("\nNúmero de columnas en el dataset:")
print(len(dataStore02.columns))
print("\nNúmero de filas y columnas en el dataset:")
print(dataStore02.shape)
print("\nNombre de columnas disponibles:")
print(dataStore02.columns)
# Out:
# Primeras filas del dataset:
#            Producto  Categoria del Producto  Precio  Costo de envio  \
# 0  Silla de oficina                 Muebles  283600           15300
# 1         Pandereta  Instrumentos musicales   76800            2300
# 2         Cama king                 Muebles  443300           23800
# 3         Cama king                 Muebles  906200           46400
# 4  Silla de oficina                 Muebles  397800           19400
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificacion  \
# 0        4/8/2021  Izabela de Leon        Medellin             1
# 1      26/11/2020   Blanca Ramirez        Medellin             3
# 2      22/10/2021  Izabela de Leon         Pereira             5
# 3        4/5/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogota             4
#
#        Metodo de pago  Cantidad de cuotas  latitud  longitud
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
# Vista preliminar de los datos:
print("\nPrimeras filas del dataset:")
print(dataStore03.head())
# Conocer el número de filas:
print("\nNúmero de filas en el dataset:")
print(len(dataStore03))
# Conocer el número de columnas:
print("\nNúmero de columnas en el dataset:")
print(len(dataStore03.columns))
print("\nNúmero de filas y columnas en el dataset:")
print(dataStore03.shape)
print("\nNombre de columnas disponibles:")
print(dataStore03.columns)
# Out:
# Primeras filas del dataset:
#             Producto  Categoria del Producto   Precio  Costo de envio  \
# 0   Secadora de ropa        Electrodomesicos  1285100           66600
# 1      Mesa de noche                 Muebles   290100           13600
# 2  Guitarra acustica  Instrumentos musicales   303500           17400
# 3  Balon de voleibol    Deportes y diversion    58800            3300
# 4            Armario                 Muebles   521100           25900
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificacion  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1       10/2/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogota             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4       12/1/2022  Blanca Ramirez          Bogota             1
#
#        Metodo de pago  Cantidad de cuotas   latitud  longitud
# 0  Tarjeta de credito                   4  11.24079 -74.19904
# ...

# %%
# Vista preliminar de los datos:
print("\nPrimeras filas del dataset:")
print(dataStore04.head())
# Conocer el número de filas:
print("\nNúmero de filas en el dataset:")
print(len(dataStore04))
# Conocer el número de columnas:
print("\nNúmero de columnas en el dataset:")
print(len(dataStore04.columns))
print("\nNúmero de filas y columnas en el dataset:")
print(dataStore04.shape)
print("\nNombre de columnas disponibles:")
print(dataStore04.columns)
# Out:
# Primeras filas del dataset:
#               Producto Categoria del Producto   Precio  Costo de envio  \
# 0         Lavavajillas       Electrodomesicos  1084800           56000
# 1             Cama box                Muebles   473800           25400
# 2  Balon de baloncesto   Deportes y diversion    23700               0
# 3  Modelado predictivo                 Libros    57700            1300
# 4          Auriculares           Electronicos   138900            5600
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificacion  \
# 0      11/11/2022    Rafael Acosta          Bogota             4
# 1        3/1/2020  Izabela de Leon          Cocuta             5
# 2      25/12/2022    Maria Alfonso        Medellin             5
# 3      23/11/2021    Lucas Olivera        Medellin             3
# 4      25/04/2022   Blanca Ramirez          Bogota             4
#
#        Metodo de pago  Cantidad de cuotas  latitud  longitud
# ...

# %% [markdown]
# # Sección 3 - **Analizamos los datos contenidos en cada csv**

# %% [markdown]
# ## **Se debe evaluar información importante como los ingresos, las categorías más vendidas, las reseñas de los clientes, los productos más vendidos y el costo por envío promedio**

# %%
# Revisamos la información de cada dataframe:
print("\nInformación general del dataset:")
dataStore01.info()
print("\nFilas aleatorias del dataset:")
dataStore01.sample(5)
# Out:
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoria del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   int64
#  3   Costo de Envio          2359 non-null   int64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificacion            2359 non-null   int64
#  8   Metodo de Pago          2359 non-null   object
#  9   Cantidad de Cuotas      2359 non-null   int64
#  10  Latitud                 2359 non-null   float64
#  11  Longitud                2359 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 221.3+ KB
#
# ...

# %%
# Revisamos la información de cada dataframe:
print("\nInformación general del dataset:")
dataStore02.info()
print("\nFilas aleatorias del dataset:")
dataStore02.sample(5)
# Out:
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoria del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   int64
#  3   Costo de envio          2359 non-null   int64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificacion            2359 non-null   int64
#  8   Metodo de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  latitud                 2359 non-null   float64
#  11  longitud                2359 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 221.3+ KB
#
# ...

# %%
# Revisamos la información de cada dataframe:
print("\nInformación general del dataset:")
dataStore03.info()
print("\nFilas aleatorias del dataset:")
dataStore03.sample(5)
# Out:
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoria del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   int64
#  3   Costo de envio          2359 non-null   int64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificacion            2359 non-null   int64
#  8   Metodo de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  latitud                 2359 non-null   float64
#  11  longitud                2359 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 221.3+ KB
#
# ...

# %%
# Revisamos la información de cada dataframe:
print("\nInformación general del dataset:")
dataStore04.info()
print("\nFilas aleatorias del dataset:")
dataStore04.sample(5)
# Out:
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoria del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   int64
#  3   Costo de envio          2358 non-null   int64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificacion            2358 non-null   int64
#  8   Metodo de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  latitud                 2358 non-null   float64
#  11  longitud                2358 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 221.2+ KB
#
# ...

# %%
# Método para una muestra en específico de una columna en un dataframe:
dataStore01['Producto'].sample(11)
# Out:
# 353     Carrito de control remoto
# 956                        Estufa
# 1457                  Auriculares
# 116       Dashboards con Power BI
# 412                     Impresora
# 1380                 Celular ABXY
# 1548                  Muneca bebe
# 2077                 Vaso termico
# 1311                   Smartwatch
# 1386            Guitarra acustica
# 1860      Bloques de construccion
# Name: Producto, dtype: object

# %%
# Método para una muestra en específico de una columna en un dataframe:
dataStore02['Precio'].sample(11)
# Out:
# 465     2889200
# 1800     661300
# 876       20100
# 784      439900
# 2201    1137200
# 965      139100
# 194      221200
# 68        43900
# 676      182400
# 1532      48100
# 1482      24400
# Name: Precio, dtype: int64

# %%
# Método para una muestra en específico de una columna en un dataframe:
dataStore02['Costo de envio'].sample(11)
# Out:
# 1105     51800
# 2287     83400
# 940      27800
# 1294      1700
# 1904     35000
# 624     137900
# 463       5200
# 1780      9900
# 1131     85100
# 700          0
# 1419     58100
# Name: Costo de envio, dtype: int64

# %%
# Método para una muestra en específico de una columna en un dataframe:
dataStore03['Lugar de Compra'].sample(11)
# Out:
# 517     Medellin
# 215       Bogota
# 649      Leticia
# 659      Pereira
# 1738    Medellin
# 1403     Leticia
# 1151    Medellin
# 74        Bogota
# 1457      Bogota
# 1916      Bogota
# 1763    Medellin
# Name: Lugar de Compra, dtype: object

# %%
# Método para una muestra en específico de una columna en un dataframe:
dataStore03['Calificacion'].sample(11)
# Out:
# 2057    5
# 411     5
# 1199    4
# 915     3
# 986     5
# 1243    5
# 633     1
# 774     5
# 372     5
# 1325    5
# 1307    5
# Name: Calificacion, dtype: int64

# %%
# Método para una muestra en específico de una columna en un dataframe:
dataStore04['Metodo de pago'].sample(11)
# Out:
# 480     Tarjeta de credito
# 1904    Tarjeta de credito
# 694     Tarjeta de credito
# 1065                 Nequi
# 505     Tarjeta de credito
# 1355    Tarjeta de credito
# 946     Tarjeta de credito
# 379                  Nequi
# 349     Tarjeta de credito
# 67                   Nequi
# 186                  Nequi
# Name: Metodo de pago, dtype: object

# %% [markdown]
# ### Diferenciación de cada dataframe con su respectivo número de tienda

# %%
# Agregar una columna al inicio de cada dataframe (archivo).
# El nombre de la columna será "Tienda" y las celdas correspondientes a dicha columna deberan llenarse con la leyenda "Tienda #":
dataStore01.insert(0, 'Tienda', 'Tienda 1')
dataStore02.insert(0, 'Tienda', 'Tienda 2')
dataStore03.insert(0, 'Tienda', 'Tienda 3')
dataStore04.insert(0, 'Tienda', 'Tienda 4')

# Si se comete algún error es posible eliminar la columna "Tienda":
# dataStore04.drop('Tienda', axis=1, inplace=True)

# Para insertar la columna al final
#dataStore01['Tienda'] = 'Tienda 1'
#dataStore02['Tienda'] = 'Tienda 2'
#dataStore03['Tienda'] = 'Tienda 3'
#dataStore04['Tienda'] = 'Tienda 4'

# %%
dataStore01.head(5)
# Out:
#      Tienda           Producto Categoria del Producto  Precio  Costo de Envio  \
# 0  Tienda 1  Asistente virtual           Electronicos  164300            6900
# 1  Tienda 1    Mesa de comedor                Muebles  192300            8400
# 2  Tienda 1      Juego de mesa               Juguetes  209600           15900
# 3  Tienda 1         Microondas      Electrodomesticos  757500           41000
# 4  Tienda 1   Silla de oficina                Muebles  335200           20200
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificacion  \
# 0      16/01/2021      Pedro Gomez          Bogota             4
# 1      18/05/2022  Beatriz Morales        Medellin             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3        3/5/2022   Juan Fernandez            Cali             4
# 4       7/11/2020    Maria Alfonso        Medellin             5
#
#        Metodo de Pago  Cantidad de Cuotas   Latitud  Longitud
# ...

# %%
dataStore02.tail(5)
# Out:
#         Tienda          Producto   Categoria del Producto   Precio  \
# 2354  Tienda 2      Set de ollas  Articulos para el hogar   140300
# 2355  Tienda 2  Lavadora de ropa         Electrodomesicos  1220100
# 2356  Tienda 2        Microondas         Electrodomesicos   797900
# 2357  Tienda 2         Iphone 15             Electronicos  2224300
# 2358  Tienda 2         Bicicleta     Deportes y diversion   551000
#
#       Costo de Envio Fecha de Compra         Vendedor Lugar de Compra  \
# 2354            8100       4/12/2022  Angel Rodriguez    Barranquilla
# 2355           65200        9/2/2020   Santiago Silva          Bogota
# 2356           42900      27/09/2022   Blanca Ramirez          Bogota
# 2357          116600      21/04/2022   Juan Fernandez        Medellin
# 2358           27500        3/9/2022    Maria Alfonso        Medellin
#
#       Calificacion      Metodo de Pago  Cantidad de Cuotas   Latitud  Longitud
# ...

# %%
dataStore03.sample(5)
# Out:
#         Tienda                   Producto  Categoria del Producto  Precio  \
# 618   Tienda 3         Cuerda para saltar    Deportes y diversion   14600
# 2182  Tienda 3                  Pandereta  Instrumentos musicales   60300
# 1352  Tienda 3  Auriculares con microfono            Electronicos   98300
# 1305  Tienda 3                    Armario                 Muebles  463400
# 344   Tienda 3            Cubo magico 8x8                Juguetes    9500
#
#       Costo de Envio Fecha de Compra         Vendedor Lugar de Compra  \
# 618                0       4/11/2021  Izabela de Leon          Bogota
# 2182            1400      25/04/2022  Beatriz Morales          Bogota
# 1352            5900        7/8/2022   Juan Fernandez            Cali
# 1305           22900      22/06/2020    Juliana Costa            Cali
# 344                0        5/1/2020      Pedro Gomez    Barranquilla
#
#       Calificacion      Metodo de Pago  Cantidad de Cuotas   Latitud  Longitud
# ...

# %%
dataStore04.sample(5)
# Out:
#         Tienda             Producto   Categoria del Producto  Precio  \
# 626   Tienda 4  Balon de baloncesto     Deportes y diversion   60500
# 226   Tienda 4    Balon de voleibol     Deportes y diversion   52500
# 2089  Tienda 4    Asistente virtual             Electronicos  133900
# 1218  Tienda 4         Set de ollas  Articulos para el hogar  197700
# 1081  Tienda 4        Kit de bancas                  Muebles  273300
#
#       Costo de Envio Fecha de Compra         Vendedor Lugar de Compra  \
# 626             3600      21/11/2020  Angel Rodriguez         Pereira
# 226             3300       5/10/2021    Rafael Acosta       Cartagena
# 2089            7500      28/02/2020    Maria Alfonso        Medellin
# 1218            8700      29/01/2022  Mariana Herrera            Cali
# 1081           14800      19/03/2023  Angel Rodriguez       Cartagena
#
#       Calificacion      Metodo de Pago  Cantidad de Cuotas   Latitud  Longitud
# ...

# %%
# Creamos una variable para guardar los 4 dataframes:
dataStores = [dataStore01, dataStore02, dataStore03, dataStore04]

# %%
# Fusionamos la información de los 4 dataframes en uno solo:
# dataStores_union = pd.concat([dataStore01, dataStore02, dataStore03, dataStore04])
dataStores_concat = pd.concat(dataStores)

# %%
# Conocer la cantidad de filas que tiene una columna:
print("\nNúmero de filas en el dataset:")
print(len(dataStores_concat))
# Out:
# Número de filas en el dataset:
# 9435

# %%
# Conocer la cantidad de filas que tiene la columna "Categoria del Producto";
print("\nNúmero de filas en la columna 'Categoria del Producto':")
print(len(dataStores_concat['Categoria del Producto']))
# Out:
# Número de filas en la columna 'Categoria del Producto':
# 9435

# %%
# Mostramos la información de la nueva variable que fusiona la información de las 4 tiendas:
print("\nInformación general del dataset:")
dataStores_concat.info()
print("\nFilas finales del dataset:")
dataStores_concat.tail(5)
# Out:
# Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9435 entries, 0 to 2357
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tienda                  9435 non-null   object
#  1   Producto                9435 non-null   object
#  2   Categoria del Producto  9435 non-null   object
#  3   Precio                  9435 non-null   int64
#  4   Costo de Envio          9435 non-null   int64
#  5   Fecha de Compra         9435 non-null   object
#  6   Vendedor                9435 non-null   object
#  7   Lugar de Compra         9435 non-null   object
#  8   Calificacion            9435 non-null   int64
#  9   Metodo de Pago          9435 non-null   object
#  10  Cantidad de Cuotas      9435 non-null   int64
#  11  Latitud                 9435 non-null   float64
#  12  Longitud                9435 non-null   float64
# dtypes: float64(2), int64(4), object(7)
# ...

# %%
# Corroboramos el tipo de datos en el nuevo dataframe que contiene la unión de la información:
print("\nMostrar los tipos de datos contenidos en el dataset:")
dataStores_concat.dtypes
# Out:
# Mostrar los tipos de datos contenidos en el dataset:
# Tienda                     object
# Producto                   object
# Categoria del Producto     object
# Precio                      int64
# Costo de Envio              int64
# Fecha de Compra            object
# Vendedor                   object
# Lugar de Compra            object
# Calificacion                int64
# Metodo de Pago             object
# Cantidad de Cuotas          int64
# Latitud                   float64
# Longitud                  float64
# dtype: object

# %%
# Mostrar el contenido de la columna "Categoria del Producto":
dataStores_concat['Categoria del Producto']
#.head(50)
#.sample(50)
#.tail(50)
# Out:
# 0                  Electronicos
# 1                       Muebles
# 2                      Juguetes
# 3             Electrodomesticos
# 4                       Muebles
#                  ...
# 2353                    Muebles
# 2354                    Muebles
# 2355       Deportes y diversion
# 2356    Articulos para el hogar
# 2357       Deportes y diversion
# Name: Categoria del Producto, Length: 9435, dtype: object

# %%
# Cambiar el nombre de una columna por otro para homogeneizar:
#dataStores_concat.rename(columns={'Categori\xada del Producto': 'Categoria del Producto'}, inplace=True)

# %%
# Conocer el número de datos contenidos en una columna:
print("\nNúmero de filas en la columna 'Categoria del Producto':")
print(len(dataStores_concat['Categoria del Producto']))
# Out:
# Número de filas en la columna 'Categoria del Producto':
# 9435

# %%
# Conocer las clasificaciones de la columna "Categoria del Producto"
print("\nDescripción de la categorias de una columna específica del dataset:")
dataStores_concat['Categoria del Producto'].unique()
# Out:
# Descripción de la categorias de una columna específica del dataset:
# array([nan, 'Muebles', 'Instrumentos musicales', 'Deportes y diversion',
#        'Electronicos', 'Articulos para el hogar', 'Juguetes',
#        'Electrodomesicos', 'Libros'], dtype=object)

# %% [markdown]
# ### Selección de Columnas para realizar los análisis necesarios

# %%
# Revisamos el nombre de las columnas del dataframe:
dataStores_concat.columns
# Out:
# Index(['Tienda', 'Producto', 'Categoria del Producto', 'Precio',
#        'Costo de Envio', 'Fecha de Compra', 'Vendedor', 'Lugar de Compra',
#        'Calificacion', 'Metodo de Pago', 'Cantidad de Cuotas', 'Latitud',
#        'Longitud'],
#       dtype='object')

# %%
# Verificamos las columnas que se necesitan para el análisis general de cada tienda para tener una lectura general de las ventas:
dataStore01[['Tienda', 'Producto', 'Categoria del Producto', 'Precio', 'Costo de Envio', 'Lugar de Compra', 'Calificacion', 'Metodo de Pago']].sample(11)
# Out:
#         Tienda                 Producto    Categoria del Producto   Precio  \
# 2089  Tienda 1                Impresora              Electronicos   244600
# 526   Tienda 1             Refrigerador         Electrodomesticos  2434000
# 45    Tienda 1                Bicicleta      Deportes y diversion   428300
# 387   Tienda 1                   Sillon                   Muebles   189900
# 2048  Tienda 1  Bloques de construccion                  Juguetes    27100
# 187   Tienda 1        Balon de voleibol      Deportes y diversion    48800
# 2210  Tienda 1         Secadora de ropa         Electrodomesticos   816500
# 1847  Tienda 1             Set de ollas  Arti­culos para el hogar   222700
# 1299  Tienda 1          Sofa reclinable                   Muebles   680200
# 2194  Tienda 1          Olla de presion  Arti­culos para el hogar    75700
# 1633  Tienda 1      Modelado predictivo                    Libros    54500
#
# ...

# %%
# Verificamos las columnas que se necesitan para el análisis general de cada tienda para tener una lectura general de las ventas:
dataStore02[['Tienda', 'Producto', 'Categoria del Producto', 'Precio', 'Costo de Envio', 'Lugar de Compra', 'Calificacion', 'Metodo de Pago']].sample(11)
# Out:
#         Tienda                   Producto   Categoria del Producto   Precio  \
# 1933  Tienda 2                    Bateria   Instrumentos musicales   574600
# 1366  Tienda 2    Bloques de construccion                 Juguetes    33200
# 215   Tienda 2                  Pandereta   Instrumentos musicales    32100
# 745   Tienda 2               Set de vasos  Articulos para el hogar    26300
# 1601  Tienda 2                   Smart TV             Electronicos  1865000
# 855   Tienda 2                  Impresora             Electronicos   253900
# 1588  Tienda 2  Iniciando en programacion                   Libros    43100
# 1114  Tienda 2              TV LED UHD 4K             Electronicos  2607700
# 956   Tienda 2                  Iphone 15             Electronicos  2117800
# 2016  Tienda 2          Ajedrez de madera                 Juguetes    30500
# 2341  Tienda 2                 Smartwatch             Electronicos   169000
#
# ...

# %%
# Verificamos las columnas que se necesitan para el análisis general de cada tienda para tener una lectura general de las ventas:
dataStore03[['Tienda', 'Producto', 'Categoria del Producto', 'Precio', 'Costo de Envio', 'Lugar de Compra', 'Calificacion', 'Metodo de Pago']].sample(11)
# Out:
#         Tienda                 Producto  Categoria del Producto   Precio  \
# 907   Tienda 3          Sofa reclinable                 Muebles   612100
# 1662  Tienda 3           Dinosaurio Rex                Juguetes    15200
# 1324  Tienda 3                Pandereta  Instrumentos musicales    97000
# 1338  Tienda 3             Refrigerador        Electrodomesicos  2064300
# 1649  Tienda 3                   Estufa        Electrodomesicos   571900
# 220   Tienda 3  Bloques de construccion                Juguetes    34700
# 1336  Tienda 3             Lavavajillas        Electrodomesicos  1127500
# 1100  Tienda 3          Mesa de comedor                 Muebles   269900
# 828   Tienda 3      Balon de baloncesto    Deportes y diversion    39400
# 1677  Tienda 3        Guitarra acustica  Instrumentos musicales   274100
# 1726  Tienda 3         Silla de oficina                 Muebles   515400
#
#       Costo de Envio Lugar de Compra  Calificacion      Metodo de Pago
# ...

# %%
# Verificamos las columnas que se necesitan para el análisis general de cada tienda para tener una lectura general de las ventas:
dataStore04[['Tienda', 'Producto', 'Categoria del Producto', 'Precio', 'Costo de Envio', 'Lugar de Compra', 'Calificacion', 'Metodo de Pago']].sample(11)
# Out:
#         Tienda           Producto  Categoria del Producto   Precio  \
# 1201  Tienda 4   Lavadora de ropa        Electrodomesicos  1555000
# 759   Tienda 4        Auriculares            Electronicos    80100
# 499   Tienda 4        Tablet ABXY            Electronicos  1351000
# 449   Tienda 4   Lavadora de ropa        Electrodomesicos  1529200
# 1517  Tienda 4           Cama box                 Muebles   702800
# 738   Tienda 4            Mochila    Deportes y diversion   107900
# 1789  Tienda 4      Mesa de noche                 Muebles   321500
# 2351  Tienda 4  Guitarra acustica  Instrumentos musicales   355000
# 917   Tienda 4          Pandereta  Instrumentos musicales    84700
# 1989  Tienda 4     Mesa de centro                 Muebles   204400
# 325   Tienda 4          Pandereta  Instrumentos musicales    38200
#
#       Costo de Envio Lugar de Compra  Calificacion      Metodo de Pago
# 1201           83500        Medellin             4  Tarjeta de credito
# ...

# %% [markdown]
# ### 1. Análisis de facturación por tienda

# %%
# Análisis de facturación Tienda 1:
facturacionDS01 = dataStore01.groupby(['Tienda', 'Metodo de Pago'])['Precio'].sum().sort_values(ascending=False)
print("\nFacturación total en la Tienda 01:")
print(facturacionDS01)
# Out:
# Facturación total en la Tienda 01:
# Tienda    Metodo de Pago
# Tienda 1  Tarjeta de credito    840665800
#           Nequi                 232609700
#           Cupon                  64105500
#           Tarjeta de debito      13499400
# Name: Precio, dtype: int64

# %%
# Análisis de facturación Tienda 2:
facturacionDS02 = dataStore02.groupby(['Tienda', 'Metodo de Pago'])['Precio'].sum().sort_values(ascending=False)
print("\nFacturación total en la Tienda 02:")
print(facturacionDS02)
# Out:
# Facturación total en la Tienda 02:
# Tienda    Metodo de Pago
# Tienda 2  Tarjeta de credito    816659500
#           Nequi                 210748800
#           Cupon                  77366600
#           Tarjeta de debito      11568600
# Name: Precio, dtype: int64

# %%
# Análisis de facturación Tienda 3:
facturacionDS03 = dataStore03.groupby(['Tienda', 'Metodo de Pago'])['Precio'].sum().sort_values(ascending=False)
print("\nFacturación total en la Tienda 03:")
print(facturacionDS03)
# Out:
# Facturación total en la Tienda 03:
# Tienda    Metodo de Pago
# Tienda 3  Tarjeta de credito    804570700
#           Nequi                 229322400
#           Cupon                  47411300
#           Tarjeta de debito      16715200
# Name: Precio, dtype: int64

# %%
# Análisis de facturación Tienda 4:
facturacionDS04 = dataStore04.groupby(['Tienda', 'Metodo de Pago'])['Precio'].sum().sort_values(ascending=False)
print("\nFacturación total en la Tienda 04:")
print(facturacionDS04)
# Out:
# Facturación total en la Tienda 04:
# Tienda    Metodo de Pago
# Tienda 4  Tarjeta de credito    768711100
#           Nequi                 208003300
#           Cupon                  46986200
#           Tarjeta de debito      14675100
# Name: Precio, dtype: int64

# %% [markdown]
# ### 2. Ventas por categoría

# %%
# Ventas por Categoría del Producto/Producto:
ventasPorCategoria = dataStores_concat.groupby(['Tienda', 'Categoria del Producto'])['Precio'].sum().unstack()
print("\nVentas por categoría y tienda:")
print(ventasPorCategoria)
# Out:
# Ventas por categoría y tienda:
# Categoria del Producto  Articulos para el hogar  Arti­culos para el hogar  \
# Tienda
# Tienda 1                                    NaN                12698400.0
# Tienda 2                             14746900.0                       NaN
# Tienda 3                             15060000.0                       NaN
# Tienda 4                             15074500.0                       NaN
#
# Categoria del Producto  Deportes y diversion  Electrodomesicos  \
# Tienda
# Tienda 1                          39290000.0               NaN
# Tienda 2                          34744500.0       348567800.0
# Tienda 3                          35593100.0       329237900.0
# Tienda 4                          33350100.0       283260200.0
#
# Categoria del Producto  Electrodomesticos  Electronicos  \
# Tienda
# Tienda 1                      363685200.0   429493500.0
# Tienda 2                              NaN   410831100.0
# ...

# %%
# Cálculo de las ventas totales por producto para cada tienda:
ventasPorCategoria = dataStores_concat.groupby(['Tienda', 'Producto'])['Precio'].sum().unstack()
print("\nVentas por categoría y tienda:")
print(ventasPorCategoria)
# Out:
# Ventas por categoría y tienda:
# Producto  Ajedrez de madera   Armario  Asistente virtual  Auriculares  \
# Tienda
# Tienda 1            1430600  29462300            8058000      5043700
# Tienda 2            1287700  26174900            7929500      3569600
# Tienda 3            1355300  24187200            8013300      3959400
# Tienda 4            1075500  16421400           10467300      3943600
#
# Producto  Auriculares con microfono  Balon de baloncesto  Balon de voleibol  \
# Tienda
# Tienda 1                    4730800              2749800            2112200
# Tienda 2                    5644300              2091300            2289600
# Tienda 3                    5970500              2478100            2333800
# Tienda 4                    6402900              2439800            2364200
#
# Producto   Bateria  Bicicleta  Bloques de construccion  ...  Set de ollas  \
# Tienda                                                  ...
# ...

# %% [markdown]
# ### 3. Calificación promedio de cada tienda

# %%
# Verificamos la información contenida en el dataset:
dataStores_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9435 entries, 0 to 2357
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tienda                  9435 non-null   object
#  1   Producto                9435 non-null   object
#  2   Categoria del Producto  9435 non-null   object
#  3   Precio                  9435 non-null   int64
#  4   Costo de Envio          9435 non-null   int64
#  5   Fecha de Compra         9435 non-null   object
#  6   Vendedor                9435 non-null   object
#  7   Lugar de Compra         9435 non-null   object
#  8   Calificacion            9435 non-null   int64
#  9   Metodo de Pago          9435 non-null   object
#  10  Cantidad de Cuotas      9435 non-null   int64
#  11  Latitud                 9435 non-null   float64
#  12  Longitud                9435 non-null   float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
# Muestra de calificación promedio para cada tienda:
calificacionTienda = dataStores_concat.groupby('Tienda')['Calificacion'].mean()
print("\nCalificación promedio por tienda:")
print(calificacionTienda)
# Out:
# Calificación promedio por tienda:
# Tienda
# Tienda 1    3.976685
# Tienda 2    4.037304
# Tienda 3    4.048326
# Tienda 4    3.995759
# Name: Calificacion, dtype: float64

# %%
# Muestra de calificación promedio para cada vendedor por tienda:
calificacionVendedores = dataStores_concat.groupby(['Tienda', 'Vendedor'])['Calificacion'].mean()
print("\nCalificación promedio por tienda:")
print(calificacionVendedores)
# Out:
# Calificación promedio por tienda:
# Tienda    Vendedor
# Tienda 1  Angel Rodriguez    4.248521
#           Beatriz Morales    4.024242
#           Blanca Ramirez     3.988889
#           Camila Rivera      3.946108
#           Felipe Santos      4.041176
#           Izabela de Leon    3.751269
#           Juan Fernandez     3.852761
#           Juliana Costa      3.982249
#           Lucas Olivera      3.933735
#           Maria Alfonso      3.884393
#           Mariana Herrera    4.000000
#           Pedro Gomez        3.940828
#           Rafael Acosta      4.070175
#           Santiago Silva     4.055556
# Tienda 2  Angel Rodriguez    4.065934
#           Beatriz Morales    3.947059
#           Blanca Ramirez     3.933735
#           Camila Rivera      4.142857
#           Felipe Santos      4.114458
#           Izabela de Leon    4.000000
#           Juan Fernandez     4.055215
#           Juliana Costa      3.938547
#           Lucas Olivera      3.946746
# ...

# %% [markdown]
# ### 4. Productos más y menos vendidos

# %%
# Sección 6: Productos más y menos vendidos:
ventasPorProducto = dataStores_concat.groupby(['Tienda', 'Producto'])['Precio'].sum()
print("\nVentas totales por producto:")
print(ventasPorProducto)
# Out:
# Ventas totales por producto:
# Tienda    Producto
# Tienda 1  Ajedrez de madera             1430600
#           Armario                      29462300
#           Asistente virtual             8058000
#           Auriculares                   5043700
#           Auriculares con microfono     4730800
#                                          ...
# Tienda 4  Smartwatch                    6774400
#           Sofa reclinable              32090700
#           TV LED UHD 4K                90295300
#           Tablet ABXY                  56723100
#           Vaso termico                  2152500
# Name: Precio, Length: 204, dtype: int64

# %%
# Lista de productos más vendidos por tienda:
productosMasVendidos = ventasPorProducto.groupby(['Tienda', 'Producto']).max()
print("\nLista de productos más vendido por tienda:")
print(productosMasVendidos)
print("\nProducto más vendido por tienda:")
productosMasVendidos.groupby('Tienda').idxmax()
# Out:
# Lista de producto más vendido por tienda:
# Tienda    Producto
# Tienda 1  Ajedrez de madera             1430600
#           Armario                      29462300
#           Asistente virtual             8058000
#           Auriculares                   5043700
#           Auriculares con microfono     4730800
#                                          ...
# Tienda 4  Smartwatch                    6774400
#           Sofa reclinable              32090700
#           TV LED UHD 4K                90295300
#           Tablet ABXY                  56723100
#           Vaso termico                  2152500
# Name: Precio, Length: 204, dtype: int64
#
# Producto más vendido por tienda:
# Tienda
# Tienda 1    (Tienda 1, TV LED UHD 4K)
# Tienda 2        (Tienda 2, Iphone 15)
# Tienda 3     (Tienda 3, Refrigerador)
# Tienda 4        (Tienda 4, Iphone 15)
# Name: Precio, dtype: object

# %%
# Lista de productos menos vendidos por tienda:
productosMenosVendidos = ventasPorProducto.groupby(['Tienda', 'Producto']).min()
print("\nLista de productos menos vendido por tienda:")
print(productosMasVendidos)
print("\nProducto menos vendido por tienda:")
productosMasVendidos.groupby('Tienda').idxmin()
# Out:
# Lista de productos menos vendido por tienda:
# Tienda    Producto
# Tienda 1  Ajedrez de madera             1430600
#           Armario                      29462300
#           Asistente virtual             8058000
#           Auriculares                   5043700
#           Auriculares con microfono     4730800
#                                          ...
# Tienda 4  Smartwatch                    6774400
#           Sofa reclinable              32090700
#           TV LED UHD 4K                90295300
#           Tablet ABXY                  56723100
#           Vaso termico                  2152500
# Name: Precio, Length: 204, dtype: int64
#
# Producto menos vendido por tienda:
# Tienda
# Tienda 1    (Tienda 1, Cuerda para saltar)
# Tienda 2       (Tienda 2, Cubo magico 8x8)
# Tienda 3       (Tienda 3, Cubo magico 8x8)
# Tienda 4    (Tienda 4, Cuerda para saltar)
# Name: Precio, dtype: object

# %% [markdown]
# ### 5. Envío promedio por tienda

# %%
dataStores_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9435 entries, 0 to 2357
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tienda                  9435 non-null   object
#  1   Producto                9435 non-null   object
#  2   Categoria del Producto  9435 non-null   object
#  3   Precio                  9435 non-null   int64
#  4   Costo de Envio          9435 non-null   int64
#  5   Fecha de Compra         9435 non-null   object
#  6   Vendedor                9435 non-null   object
#  7   Lugar de Compra         9435 non-null   object
#  8   Calificacion            9435 non-null   int64
#  9   Metodo de Pago          9435 non-null   object
#  10  Cantidad de Cuotas      9435 non-null   int64
#  11  Latitud                 9435 non-null   float64
#  12  Longitud                9435 non-null   float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
# Sección 7: Envío promedio por tienda:
costoPorEnvios = dataStores_concat.groupby(['Tienda', 'Lugar de Compra'])['Costo de Envio'].mean()
print("\nPromedio de costo de envío por tienda:")
print(costoPorEnvios)
# Out:
# Promedio de costo de envío por tienda:
# Tienda    Lugar de Compra
# Tienda 1  Armenia            17314.285714
#           Barranquilla       23708.000000
#           Bogota             23815.853659
#           Bucaramanga        30587.096774
#           Cali               28827.561837
#                                  ...
# Tienda 4  Riohacha           28972.727273
#           Santa Marta        20045.714286
#           Soacha             44750.000000
#           Valledupar         14500.000000
#           Villavicencio      12914.285714
# Name: Costo de Envio, Length: 76, dtype: float64

# %%
# Total de costo de envio por lugar de compra:
montoEnvioLocalidad = costoPorEnvios.groupby('Lugar de Compra').sum()
print("\nTotal de costo de envío por tienda:")
print(montoEnvioLocalidad)
# Out:
# Total de costo de envío por tienda:
# Lugar de Compra
# Armenia           95848.809524
# Barranquilla      90835.155761
# Bogota            98142.453520
# Bucaramanga      108603.096774
# Cali             106789.761699
# Cartagena         92383.536238
# Cocuta           108893.481487
# Inirida          138985.000000
# Leticia          101207.356016
# Manizales        102897.875458
# Medellin         101169.077367
# Neiva            116580.000000
# Pasto            110307.510870
# Pereira           92993.060269
# Riohacha          95491.266234
# Santa Marta       76310.146104
# Soacha           142378.333333
# Valledupar        93250.000000
# Villavicencio     92210.043290
# Name: Costo de Envio, dtype: float64

# %%
# Total de costo de envio por lugar de compra y por tienda:
montoEnvioPorTienda = costoPorEnvios.groupby('Tienda').sum()
print("\nTotal de costo de envío por tienda:")
print(montoEnvioPorTienda)
# Out:
# Total de costo de envío por tienda:
# Tienda
# Tienda 1    530109.537357
# Tienda 2    511896.219832
# Tienda 3    497601.350272
# Tienda 4    425668.856483
# Name: Costo de Envio, dtype: float64

# %% [markdown]
# # Sección 4 - **Crear gráficos para visualización de los datos insertos en los archivos csv**

# %% [markdown]
# ## **Decide qué tipos de gráficos utilizar para presentar los resultados de forma clara y visual. Mínimo de 3 gráficos diferentes, que pueden incluir gráficos de barras, circulares, de dispersión y otros.**

# %%
# Llamamos a la biblioteca:
plt.plot()
# Out:
# []

# %% [markdown]
# ### 1. Facturación total por tienda

# %%
# Es posible dar formato al gráfico generado:
plt.plot(datos_migrantesColombia["Año"], datos_migrantesColombia["Inmigrantes"], color="green", marker="o", linestyle="dashed")
# Escribimos los datos que queremos que se muestren en los ejes cartesianos del gráfico:
plt.xticks(["1980", "1985", "1990", "1995", "2000", "2005", "2010", "2015"])
plt.yticks([0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500])
# Asignamos el tamaño del gráfico (x,y) en pulgadas:
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# #### **Tienda 1**

# %%
# Facturación total Tienda 1:
facturacionDS01.plot(color='green', kind='bar', title='Facturación Total por Tipo de Pago | Tienda 1')
plt.ylabel('Ventas Totales (Cientos de millones)')
plt.xlabel('Tipo de Pago')
#plt.xticks(['Tarjeta de Crédito', 'Nequi', 'Cupón', 'Tarjeta de Débito'])
#plt.yticks([0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
#plt.yticks(['0', '100,000,000', '200,000,000', '300,000,000', '400,000,000', '500,000,000', '600,000,000', '700,000,000', '800,000,000', '900,000,000',])
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# #### **Tienda 2**

# %%
# Facturación total Tienda 2:
facturacionDS02.plot(color='green', kind='bar', title='Facturación Total por Tipo de Pago | Tienda 2')
plt.ylabel('Ventas Totales (Cientos de millones)')
plt.xlabel('Tipo de Pago')
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# #### **Tienda 3**

# %%
# Facturación total Tienda 3:
facturacionDS03.plot(color='green', kind='bar', title='Facturación Total por Tipo de Pago | Tienda 3')
plt.ylabel('Ventas Totales (Cientos de millones)')
plt.xlabel('Tipo de Pago')
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# #### **Tienda 4**

# %%
# 1. Facturación total Tienda 4:
facturacionDS04.plot(color='green', kind='bar', title='Facturación Total por Tipo de Pago | Tienda 4')
plt.ylabel('Ventas Totales (Cientos de millones)')
plt.xlabel('Tipo de Pago')
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# ### 2. Ventas por categoría por tienda

# %%
# Ventas por categoría por tienda:
ventasPorCategoria.plot(kind='barh', stacked=True, title='Ventas por Categoría por Tienda')
plt.ylabel('Ventas por Categoría')
plt.xlabel('Numero de Tienda')
plt.figure(figsize=(18,6))
plt.show()

# %% [markdown]
# ### 3. Calificación promedio por tienda

# %%
# Calificación promedio por tienda:
calificacionTienda.plot(kind='barh', color='orange', title='Calificación Promedio por Tienda')
plt.xlabel('Promedio de Reseñas')
plt.figure(figsize=(12,6))
plt.show()

# %%
# Calificación promedio por vendedor:
calificacionVendedores.plot(kind='barh', color='orange', title='Calificación Promedio por Vendedor')
plt.xlabel('Promedio de Reseñas por vendedor')
plt.figure(figsize=(12,12))
plt.show()

# %% [markdown]
# ### 4. Costo promedio de envíos

# %%
# Costo promedio de envío general:
costoPorEnvios.plot(kind='barh', color='green', title='Costo Promedio de Envío General')
plt.xlabel('Costo en miles de pesos colombianos')
plt.ylabel('Localidad')
plt.figure(figsize=(36,100))
plt.show()

# %%
# Monto promedio por localidad:
montoEnvioLocalidad.plot(kind='barh', color='green', title='Monto Promedio de Envío por Localidad')
plt.xlabel('Costo en miles de pesos colombianos')
plt.ylabel('Localidad')
plt.figure(figsize=(12,6))
plt.show()

# %%
# Monto promedio por tienda:
montoEnvioPorTienda.plot(kind='barh', color='green', title='Monto Promedio de Envío por Tienda')
plt.xlabel('Costo en miles de pesos colombianos')
plt.ylabel('Número de Tienda')
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# # Sección 5 - **Enviar una recomendación**

# %% [markdown]
# ## **Después del análisis, escriba un texto explicando cuál tienda debería venderse y por qué, basándose en los datos presentados**

# %% [markdown]
# Al realizar el análiss de datos de las 4 tiendas que posee el dueño, se pueden hacer las siguientes observaciones:
#
# * La tienda #4 presenta una situación preocupante desde el punto de vista comercial, logístico y de atención al cliente. En primer lugar, se ha identificado como la tienda con el volumen de ventas más bajo entre las cuatro analizadas. Este dato sugiere una posible desconexión con las necesidades de su mercado objetivo, una baja rotación de inventario o una estrategia de ventas ineficiente. Es fundamental considerar que, si una tienda no logra mantener un nivel mínimo de facturación, afecta directamente la rentabilidad global del modelo de negocio y puede representar una fuga de recursos significativos para la marca y para la empresa en general.
#
# * Además, los datos muestran una considerable variabilidad en los tiempos de envío desde esta tienda, lo que indica una logística poco consistente. Esta irregularidad puede ser el reflejo de una mala gestión del almacén, deficiencias en el transporte o problemas de coordinación interna. En un entorno altamente competitivo, los clientes priorizan experiencias de compra ágiles y confiables; por tanto, las demoras o inconsistencias en los envíos podrían estar generando una pérdida de confianza en el servicio.
#
# * Por otra parte, la tienda 4 también destaca por tener calificaciones promedio más bajas otorgadas por los clientes. Este indicador es clave, ya que refleja la percepción del consumidor sobre la calidad del servicio recibido, la atención del personal y la satisfacción general. Una mala calificación puede ser resultado de vendedores poco cindispensable implementar acciones concretas orientadas a mejorar su desempeño comercial, como reentrenar al personal, optimizar la logística, revisar el surtido de productos y ajustar la estrategia de marketing local para reconectar con su audiencia.
#
# Finalmente, los vendedores tienen calificaciones que podrían mejorar si se les brindan capacitaciones en las que su enfoque hacia los tiempos de respuesta sean menos lentos y que fortalezcan su actitud hacia los clientes con mayor empatía. Es indispensable implementar acciones concretas orientadas a mejorar su desempeño comercial, como reentrenar al personal, optimizar la logística, revisar el surtido de productos y ajustar la estrategia de marketing local para reconectar con su audiencia.
